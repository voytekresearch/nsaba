# %%
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy.io
import collections
import requests
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
import re
import random as rn
from bs4 import BeautifulSoup
import nsaba.nsaba as nsaba

# %%
def fetch_entrez_ids(term, id_num):
    entrez_ids = []
    # Phantom JS driver
    strs = ["http://www.genecards.org/Search/Keyword?startPage=0&queryString=", 
            term, "&pageSize=", str(id_num)]
    search_url = ''.join(strs)
    driver = webdriver.PhantomJS()
    driver.get(search_url)
    try:
        check = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.ID, "searchResults")))
    finally:
        search_table = driver.find_element_by_id("searchResults")
        
    top_genes = search_table.find_elements_by_class_name("gc-gene-symbol")
    gene_urls = []
    for gene in top_genes:
        el = gene.find_element_by_tag_name("a")
        gene_urls.append(el.get_attribute("href"))
        
    for gene_url in gene_urls:
        driver.get(gene_url)
        try:
            check = WebDriverWait(driver, 10).until(
                EC.presence_of_element_located((By.CLASS_NAME, "gc-subsection")))
        finally:
            subsections = driver.find_elements_by_class_name("gc-subsection")
            
        text = subsections[1].text
        result = re.search("Entrez\sGene:\s([0-9]*)", text)
        entrez_ids.append(result.group(1))
        print (entrez_ids[-1])
        
    driver.close()
    
    return entrez_ids

# %%
genes = ['MECP2', 'Staufen', 'Pumilio', 'PSD-95', 'Homer1b', 'SHANK', 'beta-neurexin',
          'NLGN1', 'MEF2', 'NPAS4', 'FMRP', 'Homer1a', 'gephyrin', 'alpha-neurexin',
          'NLGN2', 'GABAaR','GRIA1', 'GRIA2', 'GRIA3', 'GRIA4', 'GABRB1', 'GABRB2', 
          'GABRB3', 'GABRD', 'GABRE', 'GABRG1', 'GABRG2', 'GABRG3', 'GABRP', 'GABRQ',
          'GABRR1', 'GABRR2', 'GABRR3', 'GABARAP', 'GABARAPL1', 'GABARAPL2', 'GABARAPL3',
          'GABRA1', 'GABRA2', 'GABRA3', 'GABRA4', 'GABRA5', 'GABRA6']

entrez_ids = []
for gene in genes:
    entrez_ids += fetch_entrez_ids(gene, 1)
# Out:
# 4204
# 27067
# 9698
# 22839
# 9456
# 81858
# 9378
# 22871
# 4205
# 266743
# 2332
# 9456
# 10243
# 9378
# 57555
# 2562
# 2890
# 2891
# 2892
# 2893
# 2560
# 2561
# 2562
# 2563
# 2564
# 2565
# 2566
# 2567
# 2568
# 55879
# 2569
# 2570
# 200959
# 11337
# 23710
# 11345
# 23766
# 2554
# 2555
# 2556
# 2557
# 2558
# 2559

# %%
zip(genes, entrez_ids)
# Out:
# [('MECP2', u'4204'),
#  ('Staufen', u'27067'),
#  ('Pumilio', u'9698'),
#  ('PSD-95', u'22839'),
#  ('Homer1b', u'9456'),
#  ('SHANK', u'81858'),
#  ('beta-neurexin', u'9378'),
#  ('NLGN1', u'22871'),
#  ('MEF2', u'4205'),
#  ('NPAS4', u'266743'),
#  ('FMRP', u'2332'),
#  ('Homer1a', u'9456'),
#  ('gephyrin', u'10243'),
#  ('alpha-neurexin', u'9378'),
#  ('NLGN2', u'57555'),
#  ('GABAaR', u'2562'),
#  ('GRIA1', u'2890'),
#  ('GRIA2', u'2891'),
#  ('GRIA3', u'2892'),
#  ('GRIA4', u'2893'),
#  ('GABRB1', u'2560'),
#  ('GABRB2', u'2561'),
#  ('GABRB3', u'2562'),
#  ('GABRD', u'2563'),
#  ('GABRE', u'2564'),
#  ('GABRG1', u'2565'),
#  ('GABRG2', u'2566'),
#  ('GABRG3', u'2567'),
#  ('GABRP', u'2568'),
#  ('GABRQ', u'55879'),
#  ('GABRR1', u'2569'),
#  ('GABRR2', u'2570'),
#  ('GABRR3', u'200959'),
#  ('GABARAP', u'11337'),
#  ('GABARAPL1', u'23710'),
#  ('GABARAPL2', u'11345'),
#  ('GABARAPL3', u'23766'),
#  ('GABRA1', u'2554'),
#  ('GABRA2', u'2555'),
#  ('GABRA3', u'2556'),
#  ('GABRA4', u'2557'),
#  ('GABRA5', u'2558'),
#  ('GABRA6', u'2559')]

# %%
[int(eid) for eid in entrez_ids]
# Out:
# [4204,
#  27067,
#  9698,
#  22839,
#  9456,
#  81858,
#  9378,
#  22871,
#  4205,
#  266743,
#  2332,
#  9456,
#  10243,
#  9378,
#  57555,
#  2562,
#  2890,
#  2891,
#  2892,
#  2893,
#  2560,
#  2561,
#  2562,
#  2563,
#  2564,
#  2565,
#  2566,
#  2567,
#  2568,
#  55879,
#  2569,
#  2570,
#  200959,
#  11337,
#  23710,
#  11345,
#  23766,
#  2554,
#  2555,
#  2556,
#  2557,
#  2558,
#  2559]

# %%
path = '/Users/Torben/Documents/richard_xyz/subIndLoc.mat'
ns_path = "/Users/Torben/Documents/ABI analysis/current_data_new/"
aba_path = '/Users/Torben/Documents/ABI analysis/normalized_microarray_donor9861/'
nsaba.Nsaba.ns_load(ns_path)
nsaba.Nsaba.aba_load(aba_path)
dat = scipy.io.loadmat(path)
N = nsaba.Nsaba()
#N.load_ge_pickle(pkl_file='/Users/Torben/Documents/ABI analysis/normalized_microarray_donor9861/Nsaba_ABA_ge.pkl')
# Out:
# This may take a minute or two ...
# database.txt loaded.
# features.txt loaded.
# Nsaba.ns['mni_coords'] initialized.
#
# This may take a minute or two ...
# SampleAnnot.csv loaded.
# MicroarrayExpression.csv loaded.
# Probes.csv loaded.
# Nsaba.aba['mni_coords'] initialized.

# %%
N.get_aba_ge(entrez_ids)

# %%
all_coords = [];
for sub in xrange(dat['coor_all'].shape[1]):
    temp_coords = tuple(dat['coor_all'][:,sub])
    all_coords.append([temp_coords,N.coords_to_ge([temp_coords],[gene1],search_radii=10,k=1),N.coords_to_ge([temp_coords],[gene2],search_radii=10,k=1)])

# %%
np.save('ei_gene_expression_coords_donor9861_closest_point_estimation',all_coords)

# %%
total=0
for x in xrange(len(all_coords)-1):
    if len(all_coords[x][1][0]) > 0:
        total +=1
print total
# Out:
# 318

# %%
all_coords
# Out:
# [[(-50.0, 29.0, 33.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-54.0, 24.0, 25.0), array([[ 9.0334133]]), array([[ 8.80621525]])],
#  [(-58.0, 20.0, 17.0), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-59.0, 15.0, 9.0), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-58.0, 8.0, 0.0), array([[ 9.13367406]]), array([[ 8.99115028]])],
#  [(-59.0, 2.0, -7.0), array([[ 9.13367406]]), array([[ 8.99115028]])],
#  [(-14.0, 13.0, -22.0), array([[ 9.23924859]]), array([[ 8.0557026]])],
#  [(-16.0, 9.0, -27.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-18.0, 2.0, -34.0), array([[ 9.27513104]]), array([[ 8.51183483]])],
#  [(-26.0, -2.0, -36.0), array([[ 9.10227015]]), array([[ 8.76778328]])],
#  [(-36.0, -6.0, -36.0), array([[ 9.38836475]]), array([[ 8.69642316]])],
#  [(-47.0, -8.0, -33.0), array([[ 9.65416816]]), array([[ 8.81064315]])],
#  [(-58.0, -67.0, 24.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-62.0, -60.0, 16.0), array([[ 8.58968062]]), array([[ 8.89864113]])],
#  [(-65.0, -53.0, 10.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-65.0, -47.0, 4.0), array([[ 8.82437886]]), array([[ 8.54600587]])],
#  [(-66.0, -39.0, -4.0), array([[ 9.17272142]]), array([[ 8.26003793]])],
#  [(-65.0, -31.0, -9.0), array([[ 9.00304569]]), array([[ 9.33315864]])],
#  [(-17.0, -15.0, -14.0), array([[ 9.84838502]]), array([[ 8.15833871]])],
#  [(-23.0, -15.0, -16.0), array([[ 9.97010929]]), array([[ 9.24310791]])],
#  [(-28.0, -14.0, -16.0), array([[ 10.2281697]]), array([[ 8.76538801]])],
#  [(-34.0, -15.0, -17.0), array([[ 10.2281697]]), array([[ 8.76538801]])],
#  [(-40.0, -15.0, -17.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-45.0, -13.0, -18.0), array([[ 8.66741753]]), array([[ 8.82110225]])],
#  [(-51.0, -13.0, -18.0), array([[ 8.66741753]]), array([[ 8.82110225]])],
#  [(-57.0, -13.0, -18.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-34.0, -16.0, -17.0), array([[ 9.8573928]]), array([[ 8.56344924]])],
#  [(-40.0, -16.0, -17.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-45.0, -15.0, -18.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-51.0, -14.0, -18.0), array([[ 8.66741753]]), array([[ 8.82110225]])],
#  [(-62.0, -13.0, -18.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-64.0, -12.0, -20.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-69.0, -11.0, -20.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-74.0, -9.0, -18.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-20.0, -23.0, -18.0), array([[ 9.43897838]]), array([[ 8.9254286]])],
#  [(-26.0, -22.0, -18.0), array([[ 9.11342393]]), array([[ 8.44158951]])],
#  [(-31.0, -21.0, -19.0), array([[ 9.8573928]]), array([[ 8.56344924]])],
#  [(-37.0, -20.0, -19.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-42.0, -19.0, -19.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-48.0, -18.0, -18.0), array([[ 9.24737403]]), array([[ 9.01963692]])],
#  [(-53.0, -16.0, -18.0), array([[ 8.66741753]]), array([[ 8.82110225]])],
#  [(-58.0, -16.0, -17.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-37.0, -21.0, -14.0), array([[ 9.8573928]]), array([[ 8.56344924]])],
#  [(-43.0, -18.0, -15.0), array([[ 9.32024489]]), array([[ 9.21273078]])],
#  [(-48.0, -17.0, -16.0), array([[ 9.24737403]]), array([[ 9.01963692]])],
#  [(-53.0, -16.0, -16.0), array([[ 9.24737403]]), array([[ 9.01963692]])],
#  [(-58.0, -16.0, -16.0), array([[ 9.10483334]]), array([[ 8.80115268]])],
#  [(-64.0, -13.0, -21.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-69.0, -11.0, -20.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-74.0, -9.0, -18.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(40.0, 43.0, 37.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(48.0, 40.0, 31.0), array([[ 8.82230929]]), array([[ 9.00714415]])],
#  [(55.0, 33.0, 23.0), array([[ 8.82230929]]), array([[ 9.00714415]])],
#  [(59.0, 28.0, 16.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(61.0, 23.0, 6.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(59.0, 16.0, -1.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(18.0, 8.0, -23.0), array([[ 8.68473196]]), array([[ 8.6533576]])],
#  [(19.0, 2.0, -32.0), array([[ 9.41935542]]), array([[ 8.35565777]])],
#  [(25.0, -3.0, -37.0), array([[ 9.4000262]]), array([[ 8.75828314]])],
#  [(32.0, -8.0, -40.0), array([[ 9.4000262]]), array([[ 8.75828314]])],
#  [(44.0, -11.0, -39.0), array([[ 9.43398384]]), array([[ 8.45595405]])],
#  [(54.0, -13.0, -38.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(62.0, -35.0, -23.0), array([[ 8.85359064]]), array([[ 8.82827267]])],
#  [(55.0, -43.0, -23.0), array([[ 8.85359064]]), array([[ 8.82827267]])],
#  [(50.0, -51.0, -22.0), array([[ 9.3527395]]), array([[ 8.68346619]])],
#  [(43.0, -59.0, -19.0), array([[ 9.02086995]]), array([[ 8.83708023]])],
#  [(36.0, -65.0, -15.0), array([[ 8.98140713]]), array([[ 8.58267794]])],
#  [(29.0, -71.0, -11.0), array([[ 9.02453204]]), array([[ 8.69217374]])],
#  [(11.0, -5.0, -22.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(17.0, -5.0, -22.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(22.0, -6.0, -22.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(28.0, -7.0, -22.0), array([[ 9.27560943]]), array([[ 8.50669689]])],
#  [(33.0, -7.0, -21.0), array([[ 9.27560943]]), array([[ 8.50669689]])],
#  [(39.0, -8.0, -23.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(44.0, -8.0, -23.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(50.0, -9.0, -22.0), array([[ 8.89207824]]), array([[ 8.73361535]])],
#  [(24.0, -9.0, -23.0), array([[ 9.26077094]]), array([[ 8.5046727]])],
#  [(30.0, -9.0, -23.0), array([[ 8.80347366]]), array([[ 8.87077278]])],
#  [(36.0, -10.0, -23.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(41.0, -11.0, -23.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(47.0, -11.0, -21.0), array([[ 8.92665477]]), array([[ 8.43436782]])],
#  [(52.0, -12.0, -21.0), array([[ 8.92665477]]), array([[ 8.43436782]])],
#  [(58.0, -12.0, -21.0), array([[ 9.05893655]]), array([[ 8.69567056]])],
#  [(64.0, -13.0, -20.0), array([[ 9.17388041]]), array([[ 8.31820328]])],
#  [(25.0, -9.0, -20.0), array([[ 9.26077094]]), array([[ 8.5046727]])],
#  [(31.0, -10.0, -21.0), array([[ 8.80347366]]), array([[ 8.87077278]])],
#  [(37.0, -10.0, -21.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(43.0, -12.0, -21.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(49.0, -13.0, -21.0), array([[ 8.89207824]]), array([[ 8.73361535]])],
#  [(54.0, -14.0, -21.0), array([[ 9.04827826]]), array([[ 8.53158225]])],
#  [(60.0, -14.0, -21.0), array([[ 9.04827826]]), array([[ 8.53158225]])],
#  [(66.0, -15.0, -20.0), array([[ 9.17388041]]), array([[ 8.31820328]])],
#  [(22.0, -23.0, -20.0), array([[ 9.38252105]]), array([[ 8.42303882]])],
#  [(27.0, -22.0, -20.0), array([[ 8.80675092]]), array([[ 8.78278644]])],
#  [(33.0, -22.0, -21.0), array([[ 8.80675092]]), array([[ 8.78278644]])],
#  [(39.0, -21.0, -22.0), array([[ 9.30647251]]), array([[ 8.94688666]])],
#  [(43.0, -20.0, -22.0), array([[ 9.02153939]]), array([[ 8.90387231]])],
#  [(49.0, -18.0, -24.0), array([[ 8.89207824]]), array([[ 8.73361535]])],
#  [(54.0, -17.0, -24.0), array([[ 9.04827826]]), array([[ 8.53158225]])],
#  [(60.0, -16.0, -23.0), array([[ 9.17388041]]), array([[ 8.31820328]])],
#  [(-19.0, 13.0, -35.0), array([[ 8.99284159]]), array([[ 8.39925321]])],
#  [(-23.0, 20.5, -31.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-30.5, 25.0, -28.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-39.5, 25.0, -23.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-48.0, 21.0, -20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-54.5, 13.5, -18.5), array([[ 8.89951929]]), array([[ 8.74276773]])],
#  [(-60.0, 5.0, -17.0), array([[ 9.2843568]]), array([[ 8.40070052]])],
#  [(-45.0, -2.0, -36.5), array([[ 9.65416816]]), array([[ 8.81064315]])],
#  [(-52.5, -7.0, -34.0), array([[ 9.52591395]]), array([[ 8.64150296]])],
#  [(-59.0, -11.5, -28.5), array([[ 8.77656559]]), array([[ 8.5661459]])],
#  [(-18.0, -59.0, -2.0), array([[ 9.54176747]]), array([[ 8.49508729]])],
#  [(-25.0, -54.0, -8.0), array([[ 9.54176747]]), array([[ 8.49508729]])],
#  [(-31.5, -49.0, -13.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-37.5, -44.5, -18.0), array([[ 9.28138606]]), array([[ 8.48765356]])],
#  [(-46.0, -38.5, -20.5), array([[ 9.07272092]]), array([[ 9.13295734]])],
#  [(-64.0, -41.0, 45.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-67.5, -37.5, 36.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-69.5, -34.0, 27.5), array([[ 9.2959835]]), array([[ 8.46697653]])],
#  [(-70.0, -30.0, 18.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-69.5, -26.5, 9.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(44.5, 50.0, 18.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(50.5, 43.5, 13.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(55.0, 36.5, 8.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(57.0, 28.5, 3.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(58.0, 20.0, -2.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(59.0, 12.0, -6.0), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(45.5, 17.5, -29.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(52.5, 11.5, -25.5), array([[ 8.93547042]]), array([[ 8.52079179]])],
#  [(57.5, 4.0, -22.0), array([[ 9.81733217]]), array([[ 8.60857681]])],
#  [(28.0, 1.0, -35.0), array([[ 9.16934474]]), array([[ 8.53986119]])],
#  [(37.0, -2.0, -31.0), array([[ 9.33838166]]), array([[ 8.59047238]])],
#  [(46.5, -4.5, -27.5), array([[ 9.82650667]]), array([[ 9.04482806]])],
#  [(20.5, -4.0, -39.5), array([[ 9.4000262]]), array([[ 8.75828314]])],
#  [(28.0, -8.5, -43.0), array([[ 9.4000262]]), array([[ 8.75828314]])],
#  [(37.5, -10.5, -42.5), array([[ 9.155936]]), array([[ 8.79015967]])],
#  [(47.0, -12.5, -38.5), array([[ 9.43398384]]), array([[ 8.45595405]])],
#  [(55.0, -14.5, -33.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(41.0, -70.5, -12.5), array([[ 8.98140713]]), array([[ 8.58267794]])],
#  [(48.5, -65.0, -15.0), array([[ 8.86488314]]), array([[ 8.13724759]])],
#  [(55.0, -57.0, -17.0), array([[ 9.32330896]]), array([[ 8.47278732]])],
#  [(60.0, -48.0, -18.0), array([[ 9.32330896]]), array([[ 8.47278732]])],
#  [(63.0, -39.5, -18.0), array([[ 8.85359064]]), array([[ 8.82827267]])],
#  [(41.0, -40.0, 9.0), array([[ 9.44939586]]), array([[ 8.58899816]])],
#  [(51.5, -42.5, 5.5), array([[ 9.44939586]]), array([[ 8.58899816]])],
#  [(61.0, -41.5, 2.5), array([[ 9.33592143]]), array([[ 8.3842437]])],
#  [(65.5, -37.5, -1.5), array([[ 9.33592143]]), array([[ 8.3842437]])],
#  [(63.5, -31.5, -5.5), array([[ 8.93764845]]), array([[ 9.50606754]])],
#  [(-31.0, 63.0, 15.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-40.0, 57.0, 15.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-48.0, 50.5, 13.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-54.5, 43.0, 10.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-58.5, 34.5, 7.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.5, 25.5, 4.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-63.5, 16.5, 0.5), array([[ 9.04008754]]), array([[ 8.85892449]])],
#  [(-28.5, 9.0, -34.5), array([[ 8.99579939]]), array([[ 8.59593661]])],
#  [(-38.0, 8.5, -36.5), array([[ 8.83927169]]), array([[ 8.85649779]])],
#  [(-48.5, 7.0, -35.0), array([[ 8.83927169]]), array([[ 8.85649779]])],
#  [(-57.5, 3.0, -31.0), array([[ 9.52591395]]), array([[ 8.64150296]])],
#  [(-23.0, 2.0, -28.5), array([[ 9.27513104]]), array([[ 8.51183483]])],
#  [(-29.0, -2.5, -34.0), array([[ 9.10227015]]), array([[ 8.76778328]])],
#  [(-38.5, -6.0, -35.0), array([[ 9.38836475]]), array([[ 8.69642316]])],
#  [(-40.5, -71.5, -10.0), array([[ 9.40308681]]), array([[ 8.66593598]])],
#  [(-47.0, -63.5, -12.5), array([[ 9.40308681]]), array([[ 8.66593598]])],
#  [(-54.0, -55.0, -15.5), array([[ 9.00271372]]), array([[ 8.9965674]])],
#  [(-60.5, -46.5, -17.5), array([[ 9.00271372]]), array([[ 8.9965674]])],
#  [(-64.5, -36.5, -18.5), array([[ 9.09434759]]), array([[ 9.21326434]])],
#  [(3.0, -14.0, -17.0), array([[ 6.74314053]]), array([[ 7.50367355]])],
#  [(-8.5, -12.5, -16.5), array([[ 6.53915318]]), array([[ 6.7442003]])],
#  [(-20.0, -10.5, -16.0), array([[ 9.24136149]]), array([[ 8.06748938]])],
#  [(-31.5, -9.0, -16.5), array([[ 9.16074811]]), array([[ 8.39325904]])],
#  [(-42.0, -7.0, -17.5), array([[ 9.80589767]]), array([[ 8.64808231]])],
#  [(-53.0, -4.0, -18.0), array([[ 9.2843568]]), array([[ 8.40070052]])],
#  [(-64.0, -1.0, -17.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-4.5, -27.0, -16.0), array([[ 7.17129672]]), array([[ 7.64219438]])],
#  [(-15.0, -23.0, -16.0), array([[ 9.43897838]]), array([[ 8.9254286]])],
#  [(-25.5, -19.5, -16.0), array([[ 9.64364131]]), array([[ 8.81816128]])],
#  [(-36.0, -16.5, -16.5), array([[ 9.8573928]]), array([[ 8.56344924]])],
#  [(-47.0, -13.5, -17.5), array([[ 8.66741753]]), array([[ 8.82110225]])],
#  [(-58.0, -10.5, -19.0), array([[ 8.43081125]]), array([[ 8.67500253]])],
#  [(-68.0, -9.0, -18.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(27.0, 69.0, 12.0), array([[ 9.17308526]]), array([[ 8.3090425]])],
#  [(36.0, 64.0, 10.0), array([[ 9.14293466]]), array([[ 8.64509434]])],
#  [(43.5, 57.0, 7.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(50.5, 49.0, 4.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(56.0, 40.5, 0.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(58.5, 31.0, -3.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(59.5, 21.5, -6.0), array([[ 8.85222003]]), array([[ 8.50435293]])],
#  [(23.5, 9.5, -30.0), array([[ 8.68473196]]), array([[ 8.6533576]])],
#  [(31.0, 9.5, -35.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(41.5, 7.0, -37.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(51.0, 2.5, -35.5), array([[ 8.92511008]]), array([[ 8.6650981]])],
#  [(58.0, -2.5, -31.0), array([[ 9.28390833]]), array([[ 9.36454733]])],
#  [(38.5, -1.5, -38.5), array([[ 9.155936]]), array([[ 8.79015967]])],
#  [(47.0, -8.0, -35.0), array([[ 9.43398384]]), array([[ 8.45595405]])],
#  [(55.0, -13.5, -30.5), array([[ 9.04827826]]), array([[ 8.53158225]])],
#  [(54.5, -52.0, 45.5), array([[ 9.36848682]]), array([[ 8.56860585]])],
#  [(60.0, -48.0, 37.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(63.0, -43.5, 28.5), array([[ 9.1904383]]), array([[ 8.48529734]])],
#  [(64.5, -38.5, 19.5), array([[ 9.1904383]]), array([[ 8.48529734]])],
#  [(65.5, -34.0, 10.5), array([[ 9.40793081]]), array([[ 8.86898321]])],
#  [(11.0, -17.5, -14.5), array([[ 7.76811092]]), array([[ 7.8272682]])],
#  [(22.5, -16.0, -13.5), array([[ 8.07360763]]), array([[ 8.07663082]])],
#  [(33.5, -15.0, -13.0), array([[ 10.22552177]]), array([[ 8.25436264]])],
#  [(44.5, -15.0, -13.0), array([[ 9.42730867]]), array([[ 8.87312921]])],
#  [(56.0, -15.0, -12.5), array([[ 9.04662027]]), array([[ 8.97908414]])],
#  [(66.5, -15.0, -10.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(73.5, -12.5, -4.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(24.5, -26.0, -15.0), array([[ 9.05256701]]), array([[ 7.67676173]])],
#  [(35.5, -24.0, -13.0), array([[ 9.87214939]]), array([[ 7.55334716]])],
#  [(46.5, -22.0, -11.5), array([[ 9.42730867]]), array([[ 8.87312921]])],
#  [(57.0, -19.0, -10.5), array([[ 9.04662027]]), array([[ 8.97908414]])],
#  [(66.5, -14.0, -9.5), array([[ 8.64834052]]), array([[ 8.91044393]])],
#  [(73.0, -7.0, -7.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.5, 0.0, -2.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(71.5, -14.5, -25.0), array([[ 9.17388041]]), array([[ 8.31820328]])],
#  [(73.5, -20.5, -17.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(74.5, -26.5, -10.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(76.0, -33.0, -2.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(77.0, -39.5, 5.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(76.5, -46.0, 12.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(74.0, -52.0, 19.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(70.0, -6.5, -18.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(66.0, 0.5, -11.5), array([[ 8.64834052]]), array([[ 8.91044393]])],
#  [(60.5, 7.0, -5.5), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(58.5, 15.0, 1.5), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(60.0, 23.5, 8.0), array([[ 9.07606333]]), array([[ 8.69940926]])],
#  [(59.0, 31.0, 15.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(53.0, 37.0, 22.0), array([[ 8.82230929]]), array([[ 9.00714415]])],
#  [(72.0, -12.5, -11.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(68.0, -6.0, -4.5), array([[ 8.60726234]]), array([[ 8.7089339]])],
#  [(63.5, 1.5, 2.0), array([[ 8.82111395]]), array([[ 8.97490398]])],
#  [(61.5, 9.0, 9.5), array([[ 9.07606333]]), array([[ 8.69940926]])],
#  [(61.5, 17.5, 16.0), array([[ 9.07606333]]), array([[ 8.69940926]])],
#  [(61.0, 25.0, 23.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(55.5, 32.0, 30.0), array([[ 8.82230929]]), array([[ 9.00714415]])],
#  [(74.0, -19.0, -4.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(69.5, -12.0, 3.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(66.0, -4.0, 10.0), array([[ 8.964072]]), array([[ 8.72172105]])],
#  [(64.5, 3.0, 17.5), array([[ 8.94126823]]), array([[ 8.81036409]])],
#  [(63.0, 11.0, 24.5), array([[ 8.94126823]]), array([[ 8.81036409]])],
#  [(61.5, 19.0, 32.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(57.5, 26.5, 38.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.5, -25.5, 3.5), array([[ 9.03854192]]), array([[ 8.93617432]])],
#  [(70.5, -18.0, 11.0), array([[ 9.03854192]]), array([[ 8.93617432]])],
#  [(67.5, -10.5, 18.0), array([[ 8.964072]]), array([[ 8.72172105]])],
#  [(67.0, -3.0, 25.5), array([[ 9.20274807]]), array([[ 8.54229041]])],
#  [(64.5, 5.0, 32.5), array([[ 9.07135053]]), array([[ 8.94744366]])],
#  [(61.0, 12.5, 39.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(57.0, 19.5, 46.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(76.5, -32.0, 11.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(72.5, -24.0, 19.0), array([[ 9.22208427]]), array([[ 8.92822413]])],
#  [(69.5, -17.0, 26.0), array([[ 9.22208427]]), array([[ 8.92822413]])],
#  [(68.5, -9.0, 33.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(64.5, -1.5, 39.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(60.5, 6.0, 46.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(54.5, 12.5, 54.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.5, -38.5, 19.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(73.5, -30.5, 26.5), array([[ 9.02711573]]), array([[ 8.97419029]])],
#  [(70.5, -23.0, 34.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(67.0, -15.5, 40.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(62.5, -8.5, 47.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(58.0, -0.5, 54.0), array([[ 9.06332469]]), array([[ 9.0439444]])],
#  [(50.5, 5.5, 59.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(73.0, -45.0, 27.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(71.0, -37.0, 34.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(68.5, -29.0, 42.5), array([[ 9.55662238]]), array([[ 8.3706003]])],
#  [(64.0, -22.5, 47.5), array([[ 9.15249426]]), array([[ 8.4753631]])],
#  [(58.5, -15.5, 54.0), array([[ 9.42610031]]), array([[ 8.40991368]])],
#  [(53.5, -7.5, 61.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(45.5, -2.0, 64.5), array([[ 9.065057]]), array([[ 8.9012273]])],
#  [(69.5, -7.5, -25.5), array([[ 9.17388041]]), array([[ 8.31820328]])],
#  [(67.0, 0.0, -18.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(62.0, 7.0, -12.0), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(58.0, 14.0, -5.5), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(58.0, 22.0, 1.0), array([[ 8.86124853]]), array([[ 8.42448821]])],
#  [(58.5, 30.0, 7.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(55.0, 37.0, 14.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(72.0, -13.5, -18.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(69.0, -6.0, -11.5), array([[ 8.64834052]]), array([[ 8.91044393]])],
#  [(64.5, 0.5, -5.0), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(61.0, 8.0, 1.5), array([[ 9.09190418]]), array([[ 8.58372245]])],
#  [(60.5, 16.5, 8.5), array([[ 9.07606333]]), array([[ 8.69940926]])],
#  [(60.5, 24.5, 15.5), array([[ 9.07606333]]), array([[ 8.69940926]])],
#  [(57.0, 31.0, 22.5), array([[ 8.82230929]]), array([[ 9.00714415]])],
#  [(73.5, -19.5, -11.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(71.0, -12.5, -4.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(67.0, -5.0, 2.5), array([[ 8.60726234]]), array([[ 8.7089339]])],
#  [(64.0, 2.5, 10.0), array([[ 8.60726234]]), array([[ 8.7089339]])],
#  [(62.5, 10.0, 17.0), array([[ 8.94126823]]), array([[ 8.81036409]])],
#  [(62.0, 18.0, 24.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(59.5, 26.0, 31.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.0, -26.0, -3.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(72.5, -18.5, 3.5), array([[ 9.03854192]]), array([[ 8.93617432]])],
#  [(68.5, -11.0, 10.5), array([[ 8.964072]]), array([[ 8.72172105]])],
#  [(66.5, -3.5, 17.5), array([[ 9.20274807]]), array([[ 8.54229041]])],
#  [(65.0, 4.0, 25.0), array([[ 9.07135053]]), array([[ 8.94744366]])],
#  [(62.5, 12.0, 32.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(59.5, 19.5, 39.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(76.5, -32.5, 4.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(73.5, -25.0, 11.0), array([[ 9.03854192]]), array([[ 8.93617432]])],
#  [(69.5, -17.5, 18.5), array([[ 9.22208427]]), array([[ 8.92822413]])],
#  [(68.0, -10.0, 26.0), array([[ 9.20274807]]), array([[ 8.54229041]])],
#  [(66.5, -2.0, 33.0), array([[ 9.07135053]]), array([[ 8.94744366]])],
#  [(63.0, 5.5, 39.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(58.5, 12.5, 47.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(77.0, -39.0, 12.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.5, -31.0, 19.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(72.5, -23.5, 26.5), array([[ 9.22208427]]), array([[ 8.92822413]])],
#  [(70.0, -16.0, 33.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(66.5, -8.5, 40.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(62.0, -1.0, 46.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(56.5, 6.0, 53.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(75.0, -45.5, 20.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(73.5, -38.0, 27.0), array([[ 9.02711573]]), array([[ 8.97419029]])],
#  [(71.5, -30.0, 34.5), array([[ 9.55662238]]), array([[ 8.3706003]])],
#  [(67.5, -22.5, 41.5), array([[ 9.15249426]]), array([[ 8.4753631]])],
#  [(63.0, -15.5, 47.5), array([[ 9.15249426]]), array([[ 8.4753631]])],
#  [(58.5, -8.0, 54.5), array([[ 9.06332469]]), array([[ 9.0439444]])],
#  [(52.0, -1.0, 60.0), array([[ 9.065057]]), array([[ 8.9012273]])],
#  [(72.0, -51.5, 27.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(70.5, -44.0, 34.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(68.0, -36.0, 42.0), array([[ 9.55662238]]), array([[ 8.3706003]])],
#  [(65.0, -29.0, 48.5), array([[ 9.15249426]]), array([[ 8.4753631]])],
#  [(59.5, -22.5, 54.0), array([[ 9.42610031]]), array([[ 8.40991368]])],
#  [(53.5, -15.0, 60.5), array([[ 9.18514414]]), array([[ 8.40832589]])],
#  [(47.0, -8.5, 65.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(44.0, -2.0, -41.5), array([[ 9.43398384]]), array([[ 8.45595405]])],
#  [(51.5, 4.0, -38.5), array([[ 8.92511008]]), array([[ 8.6650981]])],
#  [(57.0, 8.0, -32.0), array([[ 8.93547042]]), array([[ 8.52079179]])],
#  [(31.5, -25.5, -27.0), array([[ 8.80675092]]), array([[ 8.78278644]])],
#  [(42.0, -26.5, -30.0), array([[ 9.30647251]]), array([[ 8.94688666]])],
#  [(53.5, -27.0, -31.0), array([[ 8.99503942]]), array([[ 9.1006779]])],
#  [(64.5, -26.5, -29.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(71.5, -23.0, -23.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(45.5, -62.5, 55.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(54.0, -57.0, 50.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(61.5, -50.5, 45.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-34.0, 42.0, 22.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-37.0, 42.5, 16.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-34.0, 35.5, 29.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-37.0, 36.0, 23.5), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-33.5, 28.0, 35.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-37.0, 29.5, 30.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-32.5, 21.0, 42.0), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-36.5, 22.5, 36.5), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-31.0, 13.5, 48.0), array([[ 8.97532107]]), array([[ 8.88987559]])],
#  [(-35.5, 15.5, 42.5), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-29.0, 5.5, 53.0), array([[ 9.11615604]]), array([[ 9.44692872]])],
#  [(-34.0, 7.0, 49.0), array([[ 8.93442708]]), array([[ 8.9839154]])],
#  [(-27.0, -2.0, 57.0), array([[ 9.11615604]]), array([[ 9.44692872]])],
#  [(-32.0, -0.5, 53.0), array([[ 9.11615604]]), array([[ 9.44692872]])],
#  [(-30.0, -8.0, 57.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-40.0, 36.5, 17.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-41.0, 36.5, 11.0), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-40.0, 30.0, 24.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-42.0, 30.0, 18.0), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-40.0, 24.0, 31.0), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-42.5, 23.5, 25.0), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-39.5, 17.0, 37.0), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-43.0, 17.5, 31.5), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-38.5, 9.0, 43.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-42.5, 10.0, 37.5), array([[ 9.39134505]]), array([[ 8.7039499]])],
#  [(-37.0, 1.0, 49.0), array([[ 8.93442708]]), array([[ 8.9839154]])],
#  [(-42.0, 3.0, 44.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-35.0, -6.5, 53.5), array([[ 8.93442708]]), array([[ 8.9839154]])],
#  [(-40.5, -5.0, 49.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-38.5, -12.5, 55.0), array([[ 9.30395125]]), array([[ 8.2277918]])],
#  [(-43.0, 30.0, 11.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-42.0, 29.0, 5.5), array([[ 9.21363925]]), array([[ 8.86624774]])],
#  [(-44.5, 23.5, 18.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-45.0, 23.5, 12.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-45.5, 17.0, 25.5), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-47.0, 17.0, 19.5), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-46.0, 10.5, 32.0), array([[ 9.39134505]]), array([[ 8.7039499]])],
#  [(-48.0, 11.0, 26.5), array([[ 9.39134505]]), array([[ 8.7039499]])],
#  [(-46.0, 4.0, 38.0), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-48.5, 4.0, 32.5), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-45.5, -3.0, 44.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-49.0, -2.0, 39.0), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-44.0, -11.0, 50.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-48.5, -9.0, 45.0), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-46.0, -17.5, 51.0), array([[ 9.76030903]]), array([[ 8.4974071]])],
#  [(-44.0, 22.5, 6.5), array([[ 9.27096986]]), array([[ 8.59392568]])],
#  [(-42.0, 20.5, 0.0), array([[ 9.27096986]]), array([[ 8.59392568]])],
#  [(-47.5, 17.0, 13.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-46.5, 16.0, 7.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-49.5, 11.0, 20.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-50.0, 10.5, 13.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-50.5, 4.5, 27.0), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-51.5, 4.5, 20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-51.5, -2.0, 33.5), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-52.5, -2.5, 27.0), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-52.0, -8.0, 40.0), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-53.0, -8.0, 34.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-50.5, -15.5, 45.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-53.0, -14.5, 40.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-50.0, -22.5, 45.5), array([[ 8.96173686]]), array([[ 8.84876992]])],
#  [(-44.5, 14.0, 0.5), array([[ 9.27096986]]), array([[ 8.59392568]])],
#  [(-43.0, 12.5, -5.5), array([[ 8.80951374]]), array([[ 8.66651886]])],
#  [(-49.0, 9.5, 7.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-48.0, 8.5, 1.0), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-52.0, 4.0, 13.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-52.0, 3.0, 7.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-53.5, -2.5, 20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-54.5, -2.5, 14.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-54.0, -8.5, 27.5), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-55.0, -9.5, 21.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-54.0, -14.5, 34.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-55.0, -15.0, 28.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-52.5, -21.5, 40.0), array([[ 8.95277437]]), array([[ 8.38564781]])],
#  [(-55.5, -21.5, 34.5), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-52.5, -28.5, 40.5), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-46.5, 7.0, -5.0), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-45.0, 5.0, -11.0), array([[ 8.89951929]]), array([[ 8.74276773]])],
#  [(-51.0, 2.0, 1.5), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-49.5, 1.0, -5.0), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-54.5, -3.5, 8.5), array([[ 9.52245109]]), array([[ 9.02146584]])],
#  [(-53.5, -4.5, 1.5), array([[ 9.52245109]]), array([[ 9.02146584]])],
#  [(-56.0, -9.5, 15.0), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-56.5, -10.0, 8.5), array([[ 9.52245109]]), array([[ 9.02146584]])],
#  [(-56.0, -16.0, 21.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-57.0, -16.5, 15.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-56.5, -22.0, 28.5), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-57.0, -22.5, 22.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-55.5, -28.5, 35.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-56.5, -28.0, 29.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-53.5, -34.5, 36.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-48.0, -1.0, -11.0), array([[ 9.80589767]]), array([[ 8.64808231]])],
#  [(-46.0, -2.5, -16.5), array([[ 9.12540269]]), array([[ 8.81458804]])],
#  [(-52.0, -5.5, -5.0), array([[ 9.16177561]]), array([[ 8.56327265]])],
#  [(-50.5, -7.0, -10.5), array([[ 9.16177561]]), array([[ 8.56327265]])],
#  [(-55.5, -11.0, 1.5), array([[ 9.52245109]]), array([[ 9.02146584]])],
#  [(-54.0, -12.0, -4.5), array([[ 9.35561107]]), array([[ 8.78456493]])],
#  [(-57.5, -17.0, 9.0), array([[ 9.52245109]]), array([[ 9.02146584]])],
#  [(-57.0, -17.5, 2.0), array([[ 9.35561107]]), array([[ 8.78456493]])],
#  [(-58.0, -23.0, 16.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-58.0, -24.0, 10.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-57.0, -28.5, 22.5), array([[ 9.32796095]]), array([[ 8.18886583]])],
#  [(-58.0, -29.5, 16.0), array([[ 9.32796095]]), array([[ 8.18886583]])],
#  [(-54.5, -34.0, 30.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-55.5, -35.5, 23.0), array([[ 9.32796095]]), array([[ 8.18886583]])],
#  [(-52.5, -41.0, 31.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-48.5, -8.5, -16.0), array([[ 9.16177561]]), array([[ 8.56327265]])],
#  [(-52.5, -13.5, -10.0), array([[ 9.10483334]]), array([[ 8.80115268]])],
#  [(-55.5, -18.5, -4.0), array([[ 9.35561107]]), array([[ 8.78456493]])],
#  [(-57.5, -24.5, 3.0), array([[ 9.41728699]]), array([[ 9.03235267]])],
#  [(-58.0, -30.5, 10.0), array([[ 9.50596223]]), array([[ 8.56054619]])],
#  [(-56.5, -36.5, 16.5), array([[ 9.32796095]]), array([[ 8.18886583]])],
#  [(-53.5, -42.5, 24.0), array([[ 9.24252128]]), array([[ 8.50511809]])],
#  [(-33.5, 35.0, 1.5), array([[ 9.39269988]]), array([[ 8.32362572]])],
#  [(-29.0, 34.0, 1.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-24.5, 33.0, 1.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-19.5, 32.0, 0.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-15.0, 30.5, -0.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-10.5, 29.5, -1.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-6.0, 27.5, -2.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-44.0, 30.0, 22.0), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-41.0, 38.5, 18.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-37.5, 46.5, 14.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-32.5, 54.0, 10.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-26.5, 60.5, 6.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-31.5, -15.0, 0.5), array([[ 9.73008704]]), array([[ 8.54639147]])],
#  [(-26.5, -14.5, -0.5), array([[ 8.61321438]]), array([[ 8.07050287]])],
#  [(-21.5, -14.0, -0.5), array([[ 8.02056692]]), array([[ 6.72886782]])],
#  [(-27.0, -12.0, -5.0), array([[ 8.45450824]]), array([[ 8.47836303]])],
#  [(-22.0, -12.0, -5.0), array([[ 8.24269278]]), array([[ 8.73210261]])],
#  [(-18.0, -12.0, -5.0), array([[ 8.24269278]]), array([[ 8.73210261]])],
#  [(-35.0, -9.0, -24.5), array([[ 9.16074811]]), array([[ 8.39325904]])],
#  [(-25.5, -9.0, -25.5), array([[ 9.25254991]]), array([[ 9.04838363]])],
#  [(-17.5, -5.5, -25.5), array([[ 8.77885339]]), array([[ 9.00310362]])],
#  [(-50.0, -35.5, -8.5), array([[ 9.21392054]]), array([[ 8.53547355]])],
#  [(-45.0, -43.0, -6.5), array([[ 8.95739558]]), array([[ 8.51598286]])],
#  [(-38.5, -48.5, -3.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-49.0, -50.0, 1.5), array([[ 9.47044291]]), array([[ 8.50082611]])],
#  [(-42.0, -54.0, -1.0), array([[ 9.47226318]]), array([[ 8.70602471]])],
#  [(-32.0, -56.0, -1.0), array([[ 9.54176747]]), array([[ 8.49508729]])],
#  [(-7.0, -75.5, 42.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-3.5, -79.0, 35.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-2.5, -78.5, 27.0), array([[ 9.30530826]]), array([[ 8.85230344]])],
#  [(-29.5, 42.5, 29.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-31.5, 44.5, 23.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-33.5, 36.5, 34.5), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-34.5, 39.0, 30.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-35.5, 28.5, 39.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-38.0, 31.5, 34.5), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-37.0, 19.5, 44.5), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-39.0, 23.0, 39.5), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-38.0, 11.0, 48.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-42.0, 14.5, 44.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-38.5, 2.5, 52.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-41.5, 6.5, 47.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-39.0, -7.0, 55.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-43.0, -2.0, 51.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-43.5, -12.0, 53.0), array([[ 9.30395125]]), array([[ 8.2277918]])],
#  [(-36.5, 41.0, 24.5), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-38.5, 41.0, 24.0), array([[ 8.97454124]]), array([[ 8.72804233]])],
#  [(-39.0, 34.0, 30.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-40.0, 33.5, 29.0), array([[ 9.08135153]]), array([[ 8.39212982]])],
#  [(-41.5, 26.0, 34.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-44.0, 24.5, 32.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-44.0, 18.0, 39.0), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-45.0, 16.5, 37.0), array([[ 9.0930221]]), array([[ 8.85316867]])],
#  [(-45.5, 10.0, 42.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-47.5, 7.5, 40.5), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-46.0, 2.0, 46.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-48.5, -0.5, 43.0), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-47.5, -7.0, 49.0), array([[ 9.0244723]]), array([[ 8.76911596]])],
#  [(-51.0, -8.5, 46.5), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-52.0, -18.5, 48.5), array([[ 8.96173686]]), array([[ 8.84876992]])],
#  [(-42.0, 33.5, 28.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-43.5, 35.5, 22.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-45.0, 24.0, 31.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-46.0, 27.5, 26.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-47.5, 15.0, 35.0), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-49.5, 18.5, 29.5), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-48.5, 6.0, 38.5), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-51.5, 10.5, 33.0), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-50.5, -3.0, 41.0), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-52.0, 0.5, 35.5), array([[ 9.42351032]]), array([[ 8.97386759]])],
#  [(-53.5, -11.0, 43.5), array([[ 8.75179856]]), array([[ 8.92798012]])],
#  [(-53.5, -7.5, 38.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-55.5, -20.0, 46.0), array([[ 8.96173686]]), array([[ 8.84876992]])],
#  [(-56.5, -16.5, 41.0), array([[ 9.33026968]]), array([[ 9.20861851]])],
#  [(-57.0, -26.0, 43.5), array([[ 9.19761204]]), array([[ 8.33060906]])],
#  [(-47.5, 29.5, 20.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-48.5, 30.5, 15.5), array([[ 8.99982831]]), array([[ 8.70084797]])],
#  [(-50.5, 22.0, 24.5), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-51.5, 23.0, 20.0), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-53.5, 14.0, 27.5), array([[ 9.4213499]]), array([[ 8.4640223]])],
#  [(-54.5, 15.0, 23.0), array([[ 9.0334133]]), array([[ 8.80621525]])],
#  [(-55.0, 5.0, 30.0), array([[ 9.08520157]]), array([[ 9.07679983]])],
#  [(-57.0, 6.5, 26.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-55.0, -4.0, 32.5), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-56.5, -4.0, 28.0), array([[ 9.04254675]]), array([[ 9.05908497]])],
#  [(-56.5, -13.0, 35.5), array([[ 9.33026968]]), array([[ 9.20861851]])],
#  [(-57.5, -12.0, 30.5), array([[ 9.33026968]]), array([[ 9.20861851]])],
#  [(-58.0, -22.5, 38.5), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-60.0, -21.0, 34.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-59.5, -30.0, 37.0), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-52.5, 24.0, 15.0), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-51.5, 26.5, 9.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-55.5, 16.0, 18.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-54.5, 19.0, 12.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-58.0, 7.5, 21.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-57.0, 11.0, 15.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-58.5, -2.5, 24.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-59.5, 1.0, 19.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-59.0, -12.0, 26.0), array([[ 9.33026968]]), array([[ 9.20861851]])],
#  [(-59.5, -8.5, 20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.0, -20.0, 29.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-60.0, -17.0, 23.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.5, -28.5, 32.5), array([[ 9.3008393]]), array([[ 8.50036784]])],
#  [(-62.5, -25.0, 27.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.5, -34.0, 30.5), array([[ 9.12342012]]), array([[ 8.60485353]])],
#  [(-53.5, 21.5, 6.5), array([[ 9.04008754]]), array([[ 8.85892449]])],
#  [(-53.5, 19.0, 3.0), array([[ 9.04008754]]), array([[ 8.85892449]])],
#  [(-56.0, 14.0, 9.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-56.0, 12.0, 6.5), array([[ 9.25418032]]), array([[ 8.53468022]])],
#  [(-58.5, 4.5, 13.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-59.0, 3.5, 10.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-60.5, -5.0, 15.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-60.5, -5.0, 14.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-60.5, -13.5, 17.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-60.5, -13.5, 17.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-61.5, -22.0, 21.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.0, -23.0, 20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-62.5, -30.5, 25.0), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-62.0, -31.5, 24.5), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-61.0, -39.5, 29.0), array([[ 9.12342012]]), array([[ 8.60485353]])],
#  [(-56.0, 9.5, 3.0), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-54.0, 10.5, -2.5), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-59.0, 1.5, 7.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-57.0, 4.0, 1.5), array([[ 9.13367406]]), array([[ 8.99115028]])],
#  [(-61.0, -6.0, 12.0), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-61.0, -5.0, 5.5), array([[ 9.28860127]]), array([[ 8.83244672]])],
#  [(-60.5, -13.5, 16.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-61.5, -11.0, 10.5), array([[ 9.34425782]]), array([[ 8.79961085]])],
#  [(-61.0, -23.0, 20.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-62.0, -21.0, 14.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-61.5, -32.5, 24.0), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-62.5, -29.0, 19.0), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-60.5, -40.5, 28.5), array([[ 9.12342012]]), array([[ 8.60485353]])],
#  [(-61.0, -37.5, 22.5), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-59.5, -46.0, 27.0), array([[ 9.12342012]]), array([[ 8.60485353]])],
#  [(-55.0, 5.0, -4.0), array([[ 9.10782345]]), array([[ 8.44015123]])],
#  [(-59.0, -2.5, -0.5), array([[ 9.13367406]]), array([[ 8.99115028]])],
#  [(-61.5, -10.0, 4.0), array([[ 9.28860127]]), array([[ 8.83244672]])],
#  [(-63.0, -18.5, 8.5), array([[ 9.28860127]]), array([[ 8.83244672]])],
#  [(-63.5, -27.0, 13.0),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-62.0, -34.0, 17.5), array([[ 9.30479653]]), array([[ 8.52246193]])],
#  [(-60.0, -43.0, 21.0), array([[ 9.24252128]]), array([[ 8.50511809]])],
#  [(-23.0, -8.5, -27.5), array([[ 9.25254991]]), array([[ 9.04838363]])],
#  [(-31.0, -9.0, -31.5), array([[ 9.5193747]]), array([[ 8.74122717]])],
#  [(-40.5, -7.5, -33.0), array([[ 9.17639198]]), array([[ 9.3023052]])],
#  [(-48.5, -46.0, -15.5), array([[ 8.95739558]]), array([[ 8.51598286]])],
#  [(-53.0, -36.5, -17.0), array([[ 8.93217009]]), array([[ 9.29340021]])],
#  [(-58.0, -28.5, -18.0), array([[ 9.33950928]]), array([[ 8.74250711]])],
#  [(-32.5, -56.5, -13.0), array([[ 9.33551217]]), array([[ 8.77164784]])],
#  [(-42.5, -55.5, -14.5), array([[ 9.06516547]]), array([[ 8.96285682]])],
#  [(-52.0, -53.5, -13.5), array([[ 9.00271372]]), array([[ 8.9965674]])],
#  [(10.0, 14.5, -18.5), array([[ 9.03004326]]), array([[ 8.64329972]])],
#  [(5.5, 15.5, -17.0), array([[ 9.03004326]]), array([[ 8.64329972]])],
#  [(1.0, 17.0, -15.5),
#   array([], shape=(1, 0), dtype=float64),
#   array([], shape=(1, 0), dtype=float64)],
#  [(-19.5, -19.0, -14.0), array([[ 9.84838502]]), array([[ 8.15833871]])],
#  [(-24.0, -17.5, -13.0), array([[ 9.97010929]]), array([[ 9.24310791]])],
#  [(-28.5, -16.5, -12.5), array([[ 10.05440619]]), array([[ 8.78006049]])],
#  [(-20.5, -27.0, -4.0), array([[ 7.52051538]]), array([[ 8.70369938]])],
#  [(-24.0, -24.5, -5.5), array([[ 7.54477618]]), array([[ 7.94139749]])],
#  [(-28.0, -21.5, -7.0), array([[ 9.65244671]]), array([[ 8.65676335]])]]
